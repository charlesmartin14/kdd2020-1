# %% [markdown]
# # Huggingface OpenAI GPT2 models
#
# Hugginface comes with several versions of the OpenAI GPT model for generating facke test
#
# Here, we compare the  later GPT2 models, each incresing in size

# %%
import numpy as np
import pandas as pd
import numpy as np
import scipy.sparse as sp
import random, datetime

from tqdm import tqdm

import os, gc, logging
logger = logging.getLogger()

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

import weightwatcher as ww
print("weightwatcher version {}".format(ww.__version__))
# Out:
# Using TensorFlow backend.
# weightwatcher version 0.2.7

# %%
import import_ipynb
import ModelPlots as MP
# Out:
# importing Jupyter notebook from ModelPlots.ipynb

# %%
import torch
import transformers
from transformers import OpenAIGPTModel,GPT2Model
print("transformers version {}".format(transformers.__version__))
# Out:
# INFO:transformers.file_utils:PyTorch version 1.3.1 available.
# transformers version 2.3.0

# %%
gpt2_model = GPT2Model.from_pretrained('gpt2')
gpt2_model.eval();
# Out:
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-config.json from cache at /Users/charleshmartin/.cache/torch/transformers/4be02c5697d91738003fb1685c9872f284166aa32e061576bbe6aaeb95649fcf.699bbd1c449e9861456f359d6daa51bd523ac085b4b531ab0aad5a55d091e942
# INFO:transformers.configuration_utils:Model config {
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pruned_heads": {},
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "torchscript": false,
#   "use_bfloat16": false,
#   "vocab_size": 50257
# }
#
# INFO:transformers.modeling_utils:loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-pytorch_model.bin from cache at /Users/charleshmartin/.cache/torch/transformers/4295d67f022061768f4adc386234dbdb781c814c39662dd1662221c309962c55.778cf36f5c4e5d94c8cd9cefcf2a580c8643570eb327f0d4a1f007fab2acbdf1

# %%
gpt2_medium = GPT2Model.from_pretrained('gpt2-medium')
gpt2_medium.eval();
# Out:
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-medium-config.json from cache at /Users/charleshmartin/.cache/torch/transformers/98aa65385e18b0efd17acd8bf64dcdf21406bb0c99c801c2d3c9f6bfd1f48f29.266bb9683aedfcb1f7006ad2e6894fce82b8dbbae8125f4fc8570b818005b83d
# INFO:transformers.configuration_utils:Model config {
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "predict_special_tokens": true,
#   "pruned_heads": {},
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "torchscript": false,
#   "use_bfloat16": false,
#   "vocab_size": 50257
# }
#
# INFO:transformers.modeling_utils:loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-medium-pytorch_model.bin from cache at /Users/charleshmartin/.cache/torch/transformers/4b337a4f3b7d3e1518f799e238af607498c02938a3390152aaec7d4dabca5a02.8769029be4f66a5ae1055eefdd1d11621b901d510654266b8681719fff492d6e

# %%
gpt2_large = GPT2Model.from_pretrained('gpt2-large')
gpt2_large.eval();
# Out:
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-large-config.json from cache at /Users/charleshmartin/.cache/torch/transformers/c8f887cdfff4327916f4b7ed06a379c0add42bd9c66e1fe3b4a5a8525a4b2678.e4da68877e47676a9ceb9fb82e7c751246f61bc204d806ebd36e86911e825095
# INFO:transformers.configuration_utils:Model config {
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "id2label": {
#     "0": "LABEL_0"
#   },
#   "initializer_range": 0.02,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0
#   },
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 1280,
#   "n_head": 20,
#   "n_layer": 36,
#   "n_positions": 1024,
#   "num_labels": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pruned_heads": {},
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "torchscript": false,
#   "use_bfloat16": false,
#   "vocab_size": 50257
# }
#
# INFO:transformers.modeling_utils:loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-large-pytorch_model.bin from cache at /Users/charleshmartin/.cache/torch/transformers/bcc61dff8b1b03d0fd33a1eb1dc4db00875cae33296848155c6882d4bab03db4.999a50942f8e31ea6fa89ec2580cb38fa40e3db5aa46102d0406bcfa77d9142d

# %%
gpt2_xl = GPT2Model.from_pretrained('gpt2-xl')
gpt2_xl.eval();
# Out:
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-xl-config.json from cache at /Users/charleshmartin/.cache/torch/transformers/289a4dd9ea41e5a898f64d60eab036a397782139e40973fa0b48844d9c0be2a8.fca60a45882b67807523c18622ae08509ad311594826e035c7e61c142150e80d
# INFO:transformers.configuration_utils:Model config {
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "id2label": {
#     "0": "LABEL_0"
#   },
#   "initializer_range": 0.02,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0
#   },
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 1600,
#   "n_head": 25,
#   "n_layer": 48,
#   "n_positions": 1024,
#   "num_labels": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pruned_heads": {},
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "torchscript": false,
#   "use_bfloat16": false,
#   "vocab_size": 50257
# }
#
# INFO:transformers.modeling_utils:loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-xl-pytorch_model.bin from cache at /Users/charleshmartin/.cache/torch/transformers/cb17d4cd37fbb1f4c8a40b8419e3bdeafe212f2661ef7d0c8b5dd1bdb8f874c1.7013c97af6a899790dfb77a9d9b5230945da1f17f0b79da57a8941eaa3be03ca

# %%
plt.rcParams.update({'font.size': 10})
from pylab import rcParams
rcParams['figure.figsize'] = 5,5

# %%
series_name = "GPT2"
all_models = [gpt2_model, gpt2_medium, gpt2_large, gpt2_xl]
all_names = ["gpt2 small" , "gpt2 medium", "gpt2 large", "gpt2 xl"]
colors = ['blue', 'green', 'darkorange', 'red']

# %% [markdown]
# #### TODO:
#
# catch RuntimeWarning:

# %% [markdown]
# ### This takea . few hours to run

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

all_summaries = []
all_details = []
for im, model in enumerate(tqdm(all_models)):
    watcher = ww.WeightWatcher(model=model, logger=logger)
    results = watcher.analyze(alphas=True, softranks=True, spectralnorms=True, mp_fit=True, plot=False)#, max_size=5000)

    summary =  watcher.get_summary()

    details  = watcher.get_details(results=results)
    details.drop(columns=['slice', 'slice_count'], inplace=True)
    details.dropna(inplace=True)
    details['NxM'] = pd.to_numeric(details.N * details.M) 
    
    all_summaries.append(summary)
    all_details.append(details)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:
#
# python      version 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.17.4
# tensforflow version 1.15.0
# keras       version 2.2.4
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.08103540539741516, max: 0.19961957484483284, avg: 0.1271023109924772
# INFO:__main__:Check compound: min: 0.08103540539741516, max: 0.19961957484483284, avg: 0.1271023109924772
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 44.006927490234375, max: 631.2603149414062, avg: 126.1707992553711
# INFO:__main__:Norm compound: min: 44.006927490234375, max: 631.2603149414062, avg: 126.1707992553711
# INFO:__main__:LogNorm: min: 1.6435210704803467, max: 2.800208568572998, avg: 2.0508360862731934
# INFO:__main__:LogNorm compound: min: 1.6435210704803467, max: 2.800208568572998, avg: 2.0508360862731934
# INFO:__main__:Norm X: min: 149.1733856201172, max: 109206.015625, avg: 3126.409912109375
# INFO:__main__:Norm X compound: min: 149.1733856201172, max: 109206.015625, avg: 3126.409912109375
# INFO:__main__:LogNorm X: min: 2.1736912727355957, max: 5.0382466316223145, avg: 2.938204288482666
# INFO:__main__:LogNorm X compound: min: 2.1736912727355957, max: 5.0382466316223145, avg: 2.938204288482666
# INFO:__main__:Alpha: min: 1.5522677771139286, max: 6.245504161974442, avg: 3.8335599001263265
# INFO:__main__:Alpha compound: min: 1.5522677771139286, max: 6.245504161974442, avg: 3.8335599001263265
# INFO:__main__:Alpha Weighted: min: 5.096069194158718, max: 17.651539338101593, avg: 9.780351785497595
# INFO:__main__:Alpha Weighted compound: min: 5.096069194158718, max: 17.651539338101593, avg: 9.780351785497595
# INFO:__main__:Spectral Norm: min: 82.5246810913086, max: 108374.859375, avg: 2639.267822265625
# INFO:__main__:Spectral Norm compound: min: 82.5246810913086, max: 108374.859375, avg: 2639.267822265625
# INFO:__main__:Log Spectral Norm: min: 1.9165838956832886, max: 5.034928321838379, avg: 2.5913867950439453
# INFO:__main__:Log Spectral Norm compound: min: 1.9165838956832886, max: 5.034928321838379, avg: 2.5913867950439453
# INFO:__main__:Softrank: min: 3.0852333805251635, max: 131.03886921194837, avg: 44.01511582707473
# INFO:__main__:Softrank compound: min: 3.0852333805251635, max: 131.03886921194837, avg: 44.01511582707473
# INFO:__main__:Softrank Log: min: 0.48928802154289586, max: 2.1174001367276225, avg: 1.5102401338667983
# INFO:__main__:Softrank Log compound: min: 0.48928802154289586, max: 2.1174001367276225, avg: 1.5102401338667983
# INFO:__main__:Softrank Log Ratio: min: 1.1123130321502686, max: 2.034367084503174, avg: 1.6146440505981445
# INFO:__main__:Softrank Log Ratio compound: min: 1.1123130321502686, max: 2.034367084503174, avg: 1.6146440505981445
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.285, max: 1.5782226562500008, avg: 0.6342523925781252
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.285, max: 1.5782226562500008, avg: 0.6342523925781252
# INFO:__main__:Number of spikes per MP fit: min: 25, max: 767, avg: 605.86
# INFO:__main__:Number of spikes per MP fit compound: min: 25.0, max: 767.0, avg: 605.86
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.03259452411994785, max: 1.0, avg: 0.7899087353324642
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.03259452411994785, max: 1.0, avg: 0.7899087353324642
# INFO:__main__:Softrank for MP fit: min: 1.0484580701885569e-06, max: 0.07072055877096349, avg: 0.012439115336940698
# INFO:__main__:Softrank for MP fit compound: min: 1.0484580701885569e-06, max: 0.07072055877096349, avg: 0.012439115336940698
# INFO:__main__:alpha pNorm: min: 5.520750094821698, max: 17.651546896998138, avg: 10.029035308652055
# INFO:__main__:alpha pNorm compound: min: 5.520750094821698, max: 17.651546896998138, avg: 10.029035308652055
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.08103540539741516, max: 0.19961957484483284, avg: 0.1271023109924772
# INFO:__main__:Check compound: min: 0.08103540539741516, max: 0.19961957484483284, avg: 0.1271023109924772
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 44.006927490234375, max: 631.2603149414062, avg: 126.1707992553711
# INFO:__main__:Norm compound: min: 44.006927490234375, max: 631.2603149414062, avg: 126.1707992553711
# INFO:__main__:LogNorm: min: 1.6435210704803467, max: 2.800208568572998, avg: 2.0508360862731934
# INFO:__main__:LogNorm compound: min: 1.6435210704803467, max: 2.800208568572998, avg: 2.0508360862731934
# INFO:__main__:Norm X: min: 149.1733856201172, max: 109206.015625, avg: 3126.409912109375
# INFO:__main__:Norm X compound: min: 149.1733856201172, max: 109206.015625, avg: 3126.409912109375
# INFO:__main__:LogNorm X: min: 2.1736912727355957, max: 5.0382466316223145, avg: 2.938204288482666
# INFO:__main__:LogNorm X compound: min: 2.1736912727355957, max: 5.0382466316223145, avg: 2.938204288482666
# INFO:__main__:Alpha: min: 1.5522677771139286, max: 6.245504161974442, avg: 3.8335599001263265
# INFO:__main__:Alpha compound: min: 1.5522677771139286, max: 6.245504161974442, avg: 3.8335599001263265
# INFO:__main__:Alpha Weighted: min: 5.096069194158718, max: 17.651539338101593, avg: 9.780351785497595
# INFO:__main__:Alpha Weighted compound: min: 5.096069194158718, max: 17.651539338101593, avg: 9.780351785497595
# INFO:__main__:Spectral Norm: min: 82.5246810913086, max: 108374.859375, avg: 2639.267822265625
# INFO:__main__:Spectral Norm compound: min: 82.5246810913086, max: 108374.859375, avg: 2639.267822265625
# INFO:__main__:Log Spectral Norm: min: 1.9165838956832886, max: 5.034928321838379, avg: 2.5913867950439453
# INFO:__main__:Log Spectral Norm compound: min: 1.9165838956832886, max: 5.034928321838379, avg: 2.5913867950439453
# INFO:__main__:Softrank: min: 3.0852333805251635, max: 131.03886921194837, avg: 44.01511582707473
# INFO:__main__:Softrank compound: min: 3.0852333805251635, max: 131.03886921194837, avg: 44.01511582707473
# INFO:__main__:Softrank Log: min: 0.48928802154289586, max: 2.1174001367276225, avg: 1.5102401338667983
# INFO:__main__:Softrank Log compound: min: 0.48928802154289586, max: 2.1174001367276225, avg: 1.5102401338667983
# INFO:__main__:Softrank Log Ratio: min: 1.1123130321502686, max: 2.034367084503174, avg: 1.6146440505981445
# INFO:__main__:Softrank Log Ratio compound: min: 1.1123130321502686, max: 2.034367084503174, avg: 1.6146440505981445
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.285, max: 1.5782226562500008, avg: 0.6342523925781252
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.285, max: 1.5782226562500008, avg: 0.6342523925781252
# INFO:__main__:Number of spikes per MP fit: min: 25, max: 767, avg: 605.86
# INFO:__main__:Number of spikes per MP fit compound: min: 25.0, max: 767.0, avg: 605.86
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.03259452411994785, max: 1.0, avg: 0.7899087353324642
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.03259452411994785, max: 1.0, avg: 0.7899087353324642
# INFO:__main__:Softrank for MP fit: min: 1.0484580701885569e-06, max: 0.07072055877096349, avg: 0.012439115336940698
# INFO:__main__:Softrank for MP fit compound: min: 1.0484580701885569e-06, max: 0.07072055877096349, avg: 0.012439115336940698
# INFO:__main__:alpha pNorm: min: 5.520750094821698, max: 17.651546896998138, avg: 10.029035308652055
# INFO:__main__:alpha pNorm compound: min: 5.520750094821698, max: 17.651546896998138, avg: 10.029035308652055
#  25%|██▌       | 1/4 [02:34<07:44, 154.77s/it]INFO:__main__:
#
# python      version 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.17.4
# tensforflow version 1.15.0
# keras       version 2.2.4
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.037552084773778915, max: 0.16772766061450803, avg: 0.10346191420616928
# INFO:__main__:Check compound: min: 0.037552084773778915, max: 0.16772766061450803, avg: 0.10346191420616928
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 27.190614700317383, max: 587.51171875, avg: 131.7825469970703
# INFO:__main__:Norm compound: min: 27.190614700317383, max: 587.51171875, avg: 131.7825469970703
# INFO:__main__:LogNorm: min: 1.43441903591156, max: 2.7690165042877197, avg: 2.080764055252075
# INFO:__main__:LogNorm compound: min: 1.43441903591156, max: 2.7690165042877197, avg: 2.080764055252075
# INFO:__main__:Norm X: min: 55.70621871948242, max: 107546.34375, avg: 2081.57421875
# INFO:__main__:Norm X compound: min: 55.70621871948242, max: 107546.34375, avg: 2081.57421875
# INFO:__main__:LogNorm X: min: 1.745903730392456, max: 5.031595706939697, avg: 2.934011936187744
# INFO:__main__:LogNorm X compound: min: 1.745903730392456, max: 5.031595706939697, avg: 2.934011936187744
# INFO:__main__:Alpha: min: 1.7976949968626061, max: 5.544428726027374, avg: 3.810243321967836
# INFO:__main__:Alpha compound: min: 1.7976949968626061, max: 5.544428726027374, avg: 3.810243321967836
# INFO:__main__:Alpha Weighted: min: 3.729122375789518, max: 14.754991477224978, avg: 9.736363015958243
# INFO:__main__:Alpha Weighted compound: min: 3.729122375789518, max: 14.754991477224978, avg: 9.736363015958243
# INFO:__main__:Spectral Norm: min: 14.144035339355469, max: 107123.6640625, avg: 1601.4879150390625
# INFO:__main__:Spectral Norm compound: min: 14.144035339355469, max: 107123.6640625, avg: 1601.4879150390625
# INFO:__main__:Log Spectral Norm: min: 1.1505733728408813, max: 5.029885292053223, avg: 2.577697277069092
# INFO:__main__:Log Spectral Norm compound: min: 1.1505733728408813, max: 5.029885292053223, avg: 2.577697277069092
# INFO:__main__:Softrank: min: 2.6537350247385674, max: 156.99997051174864, avg: 53.079399144522036
# INFO:__main__:Softrank compound: min: 2.6537350247385674, max: 156.99997051174864, avg: 53.079399144522036
# INFO:__main__:Softrank Log: min: 0.4238575564188011, max: 2.195899570838622, avg: 1.5837979881053115
# INFO:__main__:Softrank Log compound: min: 0.4238575564188011, max: 2.195899570838622, avg: 1.5837979881053115
# INFO:__main__:Softrank Log Ratio: min: 1.1010257005691528, max: 2.5784690380096436, avg: 1.6492944955825806
# INFO:__main__:Softrank Log Ratio compound: min: 1.1010257005691528, max: 2.5784690380096436, avg: 1.6492944955825806
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.285, max: 1.5364257812500006, avg: 0.687547159000319
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.285, max: 1.5364257812500006, avg: 0.687547159000319
# INFO:__main__:Number of spikes per MP fit: min: 9, max: 1023, avg: 806.3061224489796
# INFO:__main__:Number of spikes per MP fit compound: min: 9.0, max: 1023.0, avg: 806.3061224489796
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.008797653958944282, max: 1.0, avg: 0.7881780278093643
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.008797653958944282, max: 1.0, avg: 0.7881780278093643
# INFO:__main__:Softrank for MP fit: min: 1.0971185166213517e-06, max: 0.2839026979327251, avg: 0.014948468030232932
# INFO:__main__:Softrank for MP fit compound: min: 1.0971185166213517e-06, max: 0.2839026979327251, avg: 0.014948468030232932
# INFO:__main__:alpha pNorm: min: 4.463964520640751, max: 14.75502238020516, avg: 10.008119477388153
# INFO:__main__:alpha pNorm compound: min: 4.463964520640751, max: 14.75502238020516, avg: 10.008119477388153
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.037552084773778915, max: 0.16772766061450803, avg: 0.10346191420616928
# INFO:__main__:Check compound: min: 0.037552084773778915, max: 0.16772766061450803, avg: 0.10346191420616928
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 27.190614700317383, max: 587.51171875, avg: 131.7825469970703
# INFO:__main__:Norm compound: min: 27.190614700317383, max: 587.51171875, avg: 131.7825469970703
# INFO:__main__:LogNorm: min: 1.43441903591156, max: 2.7690165042877197, avg: 2.080764055252075
# INFO:__main__:LogNorm compound: min: 1.43441903591156, max: 2.7690165042877197, avg: 2.080764055252075
# INFO:__main__:Norm X: min: 55.70621871948242, max: 107546.34375, avg: 2081.57421875
# INFO:__main__:Norm X compound: min: 55.70621871948242, max: 107546.34375, avg: 2081.57421875
# INFO:__main__:LogNorm X: min: 1.745903730392456, max: 5.031595706939697, avg: 2.934011936187744
# INFO:__main__:LogNorm X compound: min: 1.745903730392456, max: 5.031595706939697, avg: 2.934011936187744
# INFO:__main__:Alpha: min: 1.7976949968626061, max: 5.544428726027374, avg: 3.810243321967836
# INFO:__main__:Alpha compound: min: 1.7976949968626061, max: 5.544428726027374, avg: 3.810243321967836
# INFO:__main__:Alpha Weighted: min: 3.729122375789518, max: 14.754991477224978, avg: 9.736363015958243
# INFO:__main__:Alpha Weighted compound: min: 3.729122375789518, max: 14.754991477224978, avg: 9.736363015958243
# INFO:__main__:Spectral Norm: min: 14.144035339355469, max: 107123.6640625, avg: 1601.4879150390625
# INFO:__main__:Spectral Norm compound: min: 14.144035339355469, max: 107123.6640625, avg: 1601.4879150390625
# INFO:__main__:Log Spectral Norm: min: 1.1505733728408813, max: 5.029885292053223, avg: 2.577697277069092
# INFO:__main__:Log Spectral Norm compound: min: 1.1505733728408813, max: 5.029885292053223, avg: 2.577697277069092
# INFO:__main__:Softrank: min: 2.6537350247385674, max: 156.99997051174864, avg: 53.079399144522036
# INFO:__main__:Softrank compound: min: 2.6537350247385674, max: 156.99997051174864, avg: 53.079399144522036
# INFO:__main__:Softrank Log: min: 0.4238575564188011, max: 2.195899570838622, avg: 1.5837979881053115
# INFO:__main__:Softrank Log compound: min: 0.4238575564188011, max: 2.195899570838622, avg: 1.5837979881053115
# INFO:__main__:Softrank Log Ratio: min: 1.1010257005691528, max: 2.5784690380096436, avg: 1.6492944955825806
# INFO:__main__:Softrank Log Ratio compound: min: 1.1010257005691528, max: 2.5784690380096436, avg: 1.6492944955825806
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.285, max: 1.5364257812500006, avg: 0.687547159000319
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.285, max: 1.5364257812500006, avg: 0.687547159000319
# INFO:__main__:Number of spikes per MP fit: min: 9, max: 1023, avg: 806.3061224489796
# INFO:__main__:Number of spikes per MP fit compound: min: 9.0, max: 1023.0, avg: 806.3061224489796
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.008797653958944282, max: 1.0, avg: 0.7881780278093643
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.008797653958944282, max: 1.0, avg: 0.7881780278093643
# INFO:__main__:Softrank for MP fit: min: 1.0971185166213517e-06, max: 0.2839026979327251, avg: 0.014948468030232932
# INFO:__main__:Softrank for MP fit compound: min: 1.0971185166213517e-06, max: 0.2839026979327251, avg: 0.014948468030232932
# INFO:__main__:alpha pNorm: min: 4.463964520640751, max: 14.75502238020516, avg: 10.008119477388153
# INFO:__main__:alpha pNorm compound: min: 4.463964520640751, max: 14.75502238020516, avg: 10.008119477388153
#  50%|█████     | 2/4 [10:26<08:19, 249.75s/it]INFO:__main__:
#
# python      version 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.17.4
# tensforflow version 1.15.0
# keras       version 2.2.4
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.026057810038223567, max: 0.06796995401382447, avg: 0.04840356015599555
# INFO:__main__:Check compound: min: 0.026057810038223567, max: 0.06796995401382447, avg: 0.04840356015599555
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 21.094919204711914, max: 327.1368103027344, avg: 75.65315246582031
# INFO:__main__:Norm compound: min: 21.094919204711914, max: 327.1368103027344, avg: 75.65315246582031
# INFO:__main__:LogNorm: min: 1.324177861213684, max: 2.5147294998168945, avg: 1.8496043682098389
# INFO:__main__:LogNorm compound: min: 1.324177861213684, max: 2.5147294998168945, avg: 1.8496043682098389
# INFO:__main__:Norm X: min: 37.8768424987793, max: 11624.4169921875, avg: 362.9757995605469
# INFO:__main__:Norm X compound: min: 37.8768424987793, max: 11624.4169921875, avg: 362.9757995605469
# INFO:__main__:LogNorm X: min: 1.5783737897872925, max: 4.065371036529541, avg: 2.393386125564575
# INFO:__main__:LogNorm X compound: min: 1.5783737897872925, max: 4.065371036529541, avg: 2.393386125564575
# INFO:__main__:Alpha: min: 1.8608336678707569, max: 9.08014474842131, avg: 3.959608483094036
# INFO:__main__:Alpha compound: min: 1.8608336678707569, max: 9.08014474842131, avg: 3.959608483094036
# INFO:__main__:Alpha Weighted: min: 3.090293166291235, max: 13.335386361940417, avg: 7.671887133950013
# INFO:__main__:Alpha Weighted compound: min: 3.090293166291235, max: 13.335386361940417, avg: 7.671887133950013
# INFO:__main__:Spectral Norm: min: 10.70019245147705, max: 10917.71484375, avg: 217.40440368652344
# INFO:__main__:Spectral Norm compound: min: 10.70019245147705, max: 10917.71484375, avg: 217.40440368652344
# INFO:__main__:Log Spectral Norm: min: 1.0293916463851929, max: 4.0381317138671875, avg: 1.9859955310821533
# INFO:__main__:Log Spectral Norm compound: min: 1.0293916463851929, max: 4.0381317138671875, avg: 1.9859955310821533
# INFO:__main__:Softrank: min: 3.3880249181587336, max: 193.39127904252825, avg: 65.35934352972303
# INFO:__main__:Softrank compound: min: 3.3880249181587336, max: 193.39127904252825, avg: 65.35934352972303
# INFO:__main__:Softrank Log: min: 0.5299465958083273, max: 2.286436885728869, avg: 1.713194284051249
# INFO:__main__:Softrank Log compound: min: 0.5299465958083273, max: 2.286436885728869, avg: 1.713194284051249
# INFO:__main__:Softrank Log Ratio: min: 1.2454913854599, max: 2.9157190322875977, avg: 1.9430608749389648
# INFO:__main__:Softrank Log Ratio compound: min: 1.2454913854599, max: 2.9157190322875977, avg: 1.9430608749389648
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.285, max: 1.1352539062500004, avg: 0.7974442824272261
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.285, max: 1.1352539062500004, avg: 0.7974442824272261
# INFO:__main__:Number of spikes per MP fit: min: 9, max: 1279, avg: 781.7397260273973
# INFO:__main__:Number of spikes per MP fit compound: min: 9.0, max: 1279.0, avg: 781.7397260273973
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.007036747458952306, max: 1.0, avg: 0.6112371321944919
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.007036747458952306, max: 1.0, avg: 0.6112371321944919
# INFO:__main__:Softrank for MP fit: min: 1.1084583676584191e-05, max: 0.3673202613913108, avg: 0.05930519965374188
# INFO:__main__:Softrank for MP fit compound: min: 1.1084583676584191e-05, max: 0.3673202613913108, avg: 0.05930519965374188
# INFO:__main__:alpha pNorm: min: 4.055027788989688, max: 13.335386648500709, avg: 7.942938463636623
# INFO:__main__:alpha pNorm compound: min: 4.055027788989688, max: 13.335386648500709, avg: 7.942938463636623
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.026057810038223567, max: 0.06796995401382447, avg: 0.04840356015599555
# INFO:__main__:Check compound: min: 0.026057810038223567, max: 0.06796995401382447, avg: 0.04840356015599555
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 21.094919204711914, max: 327.1368103027344, avg: 75.65315246582031
# INFO:__main__:Norm compound: min: 21.094919204711914, max: 327.1368103027344, avg: 75.65315246582031
# INFO:__main__:LogNorm: min: 1.324177861213684, max: 2.5147294998168945, avg: 1.8496043682098389
# INFO:__main__:LogNorm compound: min: 1.324177861213684, max: 2.5147294998168945, avg: 1.8496043682098389
# INFO:__main__:Norm X: min: 37.8768424987793, max: 11624.4169921875, avg: 362.9757995605469
# INFO:__main__:Norm X compound: min: 37.8768424987793, max: 11624.4169921875, avg: 362.9757995605469
# INFO:__main__:LogNorm X: min: 1.5783737897872925, max: 4.065371036529541, avg: 2.393386125564575
# INFO:__main__:LogNorm X compound: min: 1.5783737897872925, max: 4.065371036529541, avg: 2.393386125564575
# INFO:__main__:Alpha: min: 1.8608336678707569, max: 9.08014474842131, avg: 3.959608483094036
# INFO:__main__:Alpha compound: min: 1.8608336678707569, max: 9.08014474842131, avg: 3.959608483094036
# INFO:__main__:Alpha Weighted: min: 3.090293166291235, max: 13.335386361940417, avg: 7.671887133950013
# INFO:__main__:Alpha Weighted compound: min: 3.090293166291235, max: 13.335386361940417, avg: 7.671887133950013
# INFO:__main__:Spectral Norm: min: 10.70019245147705, max: 10917.71484375, avg: 217.40440368652344
# INFO:__main__:Spectral Norm compound: min: 10.70019245147705, max: 10917.71484375, avg: 217.40440368652344
# INFO:__main__:Log Spectral Norm: min: 1.0293916463851929, max: 4.0381317138671875, avg: 1.9859955310821533
# INFO:__main__:Log Spectral Norm compound: min: 1.0293916463851929, max: 4.0381317138671875, avg: 1.9859955310821533
# INFO:__main__:Softrank: min: 3.3880249181587336, max: 193.39127904252825, avg: 65.35934352972303
# INFO:__main__:Softrank compound: min: 3.3880249181587336, max: 193.39127904252825, avg: 65.35934352972303
# INFO:__main__:Softrank Log: min: 0.5299465958083273, max: 2.286436885728869, avg: 1.713194284051249
# INFO:__main__:Softrank Log compound: min: 0.5299465958083273, max: 2.286436885728869, avg: 1.713194284051249
# INFO:__main__:Softrank Log Ratio: min: 1.2454913854599, max: 2.9157190322875977, avg: 1.9430608749389648
# INFO:__main__:Softrank Log Ratio compound: min: 1.2454913854599, max: 2.9157190322875977, avg: 1.9430608749389648
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.285, max: 1.1352539062500004, avg: 0.7974442824272261
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.285, max: 1.1352539062500004, avg: 0.7974442824272261
# INFO:__main__:Number of spikes per MP fit: min: 9, max: 1279, avg: 781.7397260273973
# INFO:__main__:Number of spikes per MP fit compound: min: 9.0, max: 1279.0, avg: 781.7397260273973
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.007036747458952306, max: 1.0, avg: 0.6112371321944919
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.007036747458952306, max: 1.0, avg: 0.6112371321944919
# INFO:__main__:Softrank for MP fit: min: 1.1084583676584191e-05, max: 0.3673202613913108, avg: 0.05930519965374188
# INFO:__main__:Softrank for MP fit compound: min: 1.1084583676584191e-05, max: 0.3673202613913108, avg: 0.05930519965374188
# INFO:__main__:alpha pNorm: min: 4.055027788989688, max: 13.335386648500709, avg: 7.942938463636623
# INFO:__main__:alpha pNorm compound: min: 4.055027788989688, max: 13.335386648500709, avg: 7.942938463636623
#  75%|███████▌  | 3/4 [27:56<08:09, 489.98s/it]INFO:__main__:
#
# python      version 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.17.4
# tensforflow version 1.15.0
# keras       version 2.2.4
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.015164750814437866, max: 0.05653254605597191, avg: 0.039676792467226676
# INFO:__main__:Check compound: min: 0.015164750814437866, max: 0.05653254605597191, avg: 0.039676792467226676
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 13.725564956665039, max: 305.8015441894531, avg: 77.14187622070312
# INFO:__main__:Norm compound: min: 13.725564956665039, max: 305.8015441894531, avg: 77.14187622070312
# INFO:__main__:LogNorm: min: 1.1375302076339722, max: 2.4854397773742676, avg: 1.8591032028198242
# INFO:__main__:LogNorm compound: min: 1.1375302076339722, max: 2.4854397773742676, avg: 1.8591032028198242
# INFO:__main__:Norm X: min: 20.55879020690918, max: 9432.17578125, avg: 312.8282775878906
# INFO:__main__:Norm X compound: min: 20.55879020690918, max: 9432.17578125, avg: 312.8282775878906
# INFO:__main__:LogNorm X: min: 1.312997579574585, max: 3.97461199760437, avg: 2.3557019233703613
# INFO:__main__:LogNorm X compound: min: 1.312997579574585, max: 3.97461199760437, avg: 2.3557019233703613
# INFO:__main__:Alpha: min: 1.8896308187714521, max: 8.193728914123216, avg: 3.8059490580244435
# INFO:__main__:Alpha compound: min: 1.8896308187714521, max: 8.193728914123216, avg: 3.8059490580244435
# INFO:__main__:Alpha Weighted: min: 2.937454907371132, max: 11.235196995629323, avg: 7.168485506687012
# INFO:__main__:Alpha Weighted compound: min: 2.937454907371132, max: 11.235196995629323, avg: 7.168485506687012
# INFO:__main__:Spectral Norm: min: 8.71597957611084, max: 8889.01171875, avg: 166.7279510498047
# INFO:__main__:Spectral Norm compound: min: 8.71597957611084, max: 8889.01171875, avg: 166.7279510498047
# INFO:__main__:Log Spectral Norm: min: 0.9403162002563477, max: 3.9488534927368164, avg: 1.9159595966339111
# INFO:__main__:Log Spectral Norm compound: min: 0.9403162002563477, max: 3.9488534927368164, avg: 1.9159595966339111
# INFO:__main__:Softrank: min: 4.7029047853486805, max: 261.81068526122004, avg: 80.9429430996887
# INFO:__main__:Softrank compound: min: 4.7029047853486805, max: 261.81068526122004, avg: 80.9429430996887
# INFO:__main__:Softrank Log: min: 0.6723661861421547, max: 2.417987367406819, avg: 1.8021863874059139
# INFO:__main__:Softrank Log compound: min: 0.6723661861421547, max: 2.417987367406819, avg: 1.8021863874059139
# INFO:__main__:Softrank Log Ratio: min: 1.2588160037994385, max: 3.2588391304016113, avg: 2.030139207839966
# INFO:__main__:Softrank Log Ratio compound: min: 1.2588160037994385, max: 3.2588391304016113, avg: 2.030139207839966
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.3, max: 1.07626953125, avg: 0.8054581034552192
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.3, max: 1.07626953125, avg: 0.8054581034552192
# INFO:__main__:Number of spikes per MP fit: min: 2, max: 1599, avg: 929.8711340206186
# INFO:__main__:Number of spikes per MP fit compound: min: 2.0, max: 1599.0, avg: 929.8711340206186
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.0012507817385866166, max: 1.0, avg: 0.5815601430913669
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.0012507817385866166, max: 1.0, avg: 0.5815601430913669
# INFO:__main__:Softrank for MP fit: min: 1.4060315892446608e-05, max: 0.4449203914441464, avg: 0.06767739082817996
# INFO:__main__:Softrank for MP fit compound: min: 1.4060315892446608e-05, max: 0.4449203914441464, avg: 0.06767739082817996
# INFO:__main__:alpha pNorm: min: 3.4298029012313176, max: 11.238445018530584, avg: 7.5112627118981825
# INFO:__main__:alpha pNorm compound: min: 3.4298029012313176, max: 11.238445018530584, avg: 7.5112627118981825
# INFO:__main__:### Printing results ###
# INFO:__main__:Check: min: 0.015164750814437866, max: 0.05653254605597191, avg: 0.039676792467226676
# INFO:__main__:Check compound: min: 0.015164750814437866, max: 0.05653254605597191, avg: 0.039676792467226676
# INFO:__main__:CheckTF: min: False, max: False, avg: 0.0
# INFO:__main__:CheckTF compound: min: 0.0, max: 0.0, avg: 0.0
# INFO:__main__:Norm: min: 13.725564956665039, max: 305.8015441894531, avg: 77.14187622070312
# INFO:__main__:Norm compound: min: 13.725564956665039, max: 305.8015441894531, avg: 77.14187622070312
# INFO:__main__:LogNorm: min: 1.1375302076339722, max: 2.4854397773742676, avg: 1.8591032028198242
# INFO:__main__:LogNorm compound: min: 1.1375302076339722, max: 2.4854397773742676, avg: 1.8591032028198242
# INFO:__main__:Norm X: min: 20.55879020690918, max: 9432.17578125, avg: 312.8282775878906
# INFO:__main__:Norm X compound: min: 20.55879020690918, max: 9432.17578125, avg: 312.8282775878906
# INFO:__main__:LogNorm X: min: 1.312997579574585, max: 3.97461199760437, avg: 2.3557019233703613
# INFO:__main__:LogNorm X compound: min: 1.312997579574585, max: 3.97461199760437, avg: 2.3557019233703613
# INFO:__main__:Alpha: min: 1.8896308187714521, max: 8.193728914123216, avg: 3.8059490580244435
# INFO:__main__:Alpha compound: min: 1.8896308187714521, max: 8.193728914123216, avg: 3.8059490580244435
# INFO:__main__:Alpha Weighted: min: 2.937454907371132, max: 11.235196995629323, avg: 7.168485506687012
# INFO:__main__:Alpha Weighted compound: min: 2.937454907371132, max: 11.235196995629323, avg: 7.168485506687012
# INFO:__main__:Spectral Norm: min: 8.71597957611084, max: 8889.01171875, avg: 166.7279510498047
# INFO:__main__:Spectral Norm compound: min: 8.71597957611084, max: 8889.01171875, avg: 166.7279510498047
# INFO:__main__:Log Spectral Norm: min: 0.9403162002563477, max: 3.9488534927368164, avg: 1.9159595966339111
# INFO:__main__:Log Spectral Norm compound: min: 0.9403162002563477, max: 3.9488534927368164, avg: 1.9159595966339111
# INFO:__main__:Softrank: min: 4.7029047853486805, max: 261.81068526122004, avg: 80.9429430996887
# INFO:__main__:Softrank compound: min: 4.7029047853486805, max: 261.81068526122004, avg: 80.9429430996887
# INFO:__main__:Softrank Log: min: 0.6723661861421547, max: 2.417987367406819, avg: 1.8021863874059139
# INFO:__main__:Softrank Log compound: min: 0.6723661861421547, max: 2.417987367406819, avg: 1.8021863874059139
# INFO:__main__:Softrank Log Ratio: min: 1.2588160037994385, max: 3.2588391304016113, avg: 2.030139207839966
# INFO:__main__:Softrank Log Ratio compound: min: 1.2588160037994385, max: 3.2588391304016113, avg: 2.030139207839966
# INFO:__main__:Marchenko-Pastur (MP) fit sigma: min: 0.3, max: 1.07626953125, avg: 0.8054581034552192
# INFO:__main__:Marchenko-Pastur (MP) fit sigma compound: min: 0.3, max: 1.07626953125, avg: 0.8054581034552192
# INFO:__main__:Number of spikes per MP fit: min: 2, max: 1599, avg: 929.8711340206186
# INFO:__main__:Number of spikes per MP fit compound: min: 2.0, max: 1599.0, avg: 929.8711340206186
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals: min: 0.0012507817385866166, max: 1.0, avg: 0.5815601430913669
# INFO:__main__:aka, percent_mass, Number of spikes / total number of evals compound: min: 0.0012507817385866166, max: 1.0, avg: 0.5815601430913669
# INFO:__main__:Softrank for MP fit: min: 1.4060315892446608e-05, max: 0.4449203914441464, avg: 0.06767739082817996
# INFO:__main__:Softrank for MP fit compound: min: 1.4060315892446608e-05, max: 0.4449203914441464, avg: 0.06767739082817996
# INFO:__main__:alpha pNorm: min: 3.4298029012313176, max: 11.238445018530584, avg: 7.5112627118981825
# INFO:__main__:alpha pNorm compound: min: 3.4298029012313176, max: 11.238445018530584, avg: 7.5112627118981825
# 100%|██████████| 4/4 [1:05:42<00:00, 985.68s/it]

# %%
plt.rcParams.update({'font.size': 20})
from pylab import rcParams
rcParams['figure.figsize'] = 10,10

# %%
#not executed here
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (10, 7),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
MP.plot_all_metric_histograms( \
    series_name, all_names, colors, all_summaries, all_details, [1,2,3])
# Out:
# saving img/GPT2_all_lognorm_hist.png
# saving img/GPT2_fnl_lognorm_hist.png
# saving img/GPT2_all_alpha_hist.png
# saving img/GPT2_fnl_alpha_hist.png
# saving img/GPT2_all_alpha_weighted_hist.png
# saving img/GPT2_fnl_alpha_weighted_hist.png
# saving img/GPT2_all_softranklog_hist.png
# saving img/GPT2_fnl_softranklog_hist.png
# saving img/GPT2_all_spectralnorm_hist.png
# saving img/GPT2_fnl_spectralnorm_hist.png
# saving img/GPT2_all_softrank_mp_hist.png
# saving img/GPT2_fnl_softrank_mp_hist.png
# saving img/GPT2_all_logpnorm_hist.png
# saving img/GPT2_fnl_logpnorm_hist.png

# %%
MP.plot_all_metric_vs_depth( \
    series_name, all_names, colors, all_summaries, all_details, [0,2])
# Out:
# saving img/GPT2_all_lognorm_depth.png
# saving img/GPT2_fnl_lognorm_depth.png
# saving img/GPT2_all_alpha_depth.png
# saving img/GPT2_fnl_alpha_depth.png
# saving img/GPT2_all_alpha_weighted_depth.png
# saving img/GPT2_fnl_alpha_weighted_depth.png
# saving img/GPT2_all_softranklog_depth.png
# saving img/GPT2_fnl_softranklog_depth.png
# saving img/GPT2_all_spectralnorm_depth.png
# saving img/GPT2_fnl_spectralnorm_depth.png
# saving img/GPT2_all_softrank_mp_depth.png
# saving img/GPT2_fnl_softrank_mp_depth.png
# saving img/GPT2_all_logpnorm_depth.png
# saving img/GPT2_fnl_logpnorm_depth.png

# %%
d = all_details[0]
d2 = d[d.logspectralnorm<5]
len(d), len(d2)
# Out:
# (100, 98)

# %% [markdown]
# ### max Filter on details does not work..so remove layers here

# %%
def avglogmetric(d, col):
    norm = d[col].to_numpy(dtype=np.float)
    lognorm=np.log10(norm)
    avglognorm = np.average(lognorm)
    return avglognorm

def avgmetric(d, col):
    norm = d[col].to_numpy(dtype=np.float)
    avgnorm = np.average(norm)
    return avgnorm

for idx, d in enumerate((all_details)):
    s = all_summaries[idx]
    name = all_names[idx]
    name = name.replace('gpt2_','GPT2 ')
    name = name.replace('gpt2','GPT2')

    d = d[d.level==ww.LEVEL.SLICE]
    d = d.loc[2:]

    avglognorm = avglogmetric(d, 'norm')
    avglogsnorm = avglogmetric(d, 'spectralnorm')
    avgwalpha = avgmetric(d, 'alpha_weighted')
    avglogpnorm = avgmetric(d, 'logpnorm')
    
    line = " & {} & {:.2f} &{:.2f}& {:.2f} & {:.2f} \\\\"
    print(name+line.format(len(d),avglognorm,avglogsnorm,avgwalpha,avglogpnorm))
# Out:
# GPT2 small & 49 & 2.04 &2.54& 9.62 & 9.87 \\
# GPT2 medium & 97 & 2.07 &2.55& 9.68 & 9.96 \\
# GPT2 large & 145 & 1.85 &1.97& 7.65 & 7.92 \\
# GPT2 xl & 193 & 1.86 &1.91& 7.15 & 7.49 \\

# %% [markdown]
# ### Remove  outliers of Spectral Norm and redo plots

# %%
smaller_details = [d[d.logspectralnorm<3.5] for d in all_details]

# %%
for s in smaller_details:
    print(s.logspectralnorm.max())
# Out:
# 3.28298282623291
# 3.4309301376342773
# 2.784118175506592
# 2.7362897396087646

# %%
print(all_names)
len(smaller_details), len(all_summaries)
# Out:
# ['gpt2 small', 'gpt2 medium', 'gpt2 large', 'gpt2 xl']
# (4, 4)

# %%
MP.plot_all_metric_histograms( \
    series_name+"*", all_names, colors, all_summaries, smaller_details, [1,2,3])
# Out:
# saving img/GPT2*_all_lognorm_hist.png
# saving img/GPT2*_fnl_lognorm_hist.png
# saving img/GPT2*_all_alpha_hist.png
# saving img/GPT2*_fnl_alpha_hist.png
# saving img/GPT2*_all_alpha_weighted_hist.png
# saving img/GPT2*_fnl_alpha_weighted_hist.png
# saving img/GPT2*_all_softranklog_hist.png
# saving img/GPT2*_fnl_softranklog_hist.png
# saving img/GPT2*_all_spectralnorm_hist.png
# saving img/GPT2*_fnl_spectralnorm_hist.png
# saving img/GPT2*_all_softrank_mp_hist.png
# saving img/GPT2*_fnl_softrank_mp_hist.png
# saving img/GPT2*_all_logpnorm_hist.png
# saving img/GPT2*_fnl_logpnorm_hist.png
